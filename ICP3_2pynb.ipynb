# %%
import numpy as np
import matplotlib.pyplot as plt
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense
from keras.utils import to_categorical

# Load the MNIST dataset
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()

# Process the data
dimData = np.prod(train_images.shape[1:])
train_data = train_images.reshape(train_images.shape[0], dimData)
test_data = test_images.reshape(test_images.shape[0], dimData)

# Convert data to float and scale values between 0 and 1
train_data = train_data.astype('float32')
test_data = test_data.astype('float32')
train_data /= 255.0
test_data /= 255.0

# Change the labels from integer to one-hot encoding
train_labels_one_hot = to_categorical(train_labels)
test_labels_one_hot = to_categorical(test_labels)

# Creating the network
model = Sequential()
model.add(Dense(512, activation='relu', input_shape=(dimData,)))
model.add(Dense(512, activation='relu'))
model.add(Dense(10, activation='softmax'))

model.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])

# Train the model
history = model.fit(train_data, train_labels_one_hot, batch_size=256, epochs=10, verbose=1,
                    validation_data=(test_data, test_labels_one_hot))

# Task 1: Plot the loss and accuracy for both training data and validation data
def plot_history(history):
    plt.figure(figsize=(12, 4))

    plt.subplot(1, 2, 1)
    plt.plot(history.history['loss'], label='Training Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title('Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(history.history['accuracy'], label='Training Accuracy')
    plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
    plt.title('Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()

    plt.show()

plot_history(history)

# Task 2: Plot one of the images in the test data and predict
def plot_image_and_predict(index):
    plt.imshow(test_images[index], cmap='gray')
    plt.title(f"True Label: {test_labels[index]}")
    plt.show()

    # Preprocess the image
    img = test_images[index].reshape(1, dimData).astype('float32') / 255.0

    # Predict the class
    prediction = model.predict(img)
    predicted_class = np.argmax(prediction)
    print(f"Predicted Label: {predicted_class}")

plot_image_and_predict(0)

# Task 3: Change the number of hidden layers and activation function to tanh or sigmoid
def build_and_train_model(layers, activation):
    model = Sequential()
    model.add(Dense(512, activation=activation, input_shape=(dimData,)))
    for _ in range(layers - 1):
        model.add(Dense(512, activation=activation))
    model.add(Dense(10, activation='softmax'))

    model.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])
    history = model.fit(train_data, train_labels_one_hot, batch_size=256, epochs=10, verbose=1,
                        validation_data=(test_data, test_labels_one_hot))
    return history

# Example with 3 hidden layers and 'tanh' activation
history_tanh = build_and_train_model(3, 'tanh')
plot_history(history_tanh)

# Example with 3 hidden layers and 'sigmoid' activation
history_sigmoid = build_and_train_model(3, 'sigmoid')
plot_history(history_sigmoid)

# Task 4: Run the same code without scaling the images and check the performance
train_data_no_scale = train_images.reshape(train_images.shape[0], dimData).astype('float32')
test_data_no_scale = test_images.reshape(test_images.shape[0], dimData).astype('float32')

model_no_scale = Sequential()
model_no_scale.add(Dense(512, activation='relu', input_shape=(dimData,)))
model_no_scale.add(Dense(512, activation='relu'))
model_no_scale.add(Dense(10, activation='softmax'))

model_no_scale.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])

history_no_scale = model_no_scale.fit(train_data_no_scale, train_labels_one_hot, batch_size=256, epochs=10, verbose=1,
                                      validation_data=(test_data_no_scale, test_labels_one_hot))

plot_history(history_no_scale)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step
# Epoch 1/10
# 235/235 [==============================] - 20s 72ms/step - loss: 0.2868 - accuracy: 0.9121 - val_loss: 0.1858 - val_accuracy: 0.9358
# Epoch 2/10
# 235/235 [==============================] - 9s 37ms/step - loss: 0.0998 - accuracy: 0.9691 - val_loss: 0.0860 - val_accuracy: 0.9737
# Epoch 3/10
# 235/235 [==============================] - 10s 43ms/step - loss: 0.0627 - accuracy: 0.9807 - val_loss: 0.0787 - val_accuracy: 0.9759
# Epoch 4/10
# 235/235 [==============================] - 10s 42ms/step - loss: 0.0437 - accuracy: 0.9862 - val_loss: 0.0975 - val_accuracy: 0.9705
# Epoch 5/10
# 235/235 [==============================] - 9s 37ms/step - loss: 0.0318 - accuracy: 0.9900 - val_loss: 0.0553 - val_accuracy: 0.9823
# Epoch 6/10
# 235/235 [==============================] - 8s 35ms/step - loss: 0.0225 - accuracy: 0.9931 - val_loss: 0.0638 - val_accuracy: 0.9822
# Epoch 7/10
# 235/235 [==============================] - 7s 31ms/step - loss: 0.0167 - accuracy: 0.9948 - val_loss: 0.0673 - val_accuracy: 0.9812
# Epoch 8/10
# 235/235 [==============================] - 6s 27ms/step - loss: 0.0129 - accuracy: 0.9958 - val_loss: 0.0619 - val_accuracy: 0.9834
# Epoch 9/10
# 235/235 [==============================] - 7s 30ms/step - loss: 0.0103 - accuracy: 0.9968 - val_loss: 0.0688 - val_accuracy: 0.9824
# Epoch 10/10
# 235/235 [==============================] - 6s 26ms/step - loss: 0.0076 - accuracy: 0.9977 - val_loss: 0.0682 - val_accuracy: 0.9825
# 1/1 [==============================] - 0s 138ms/step
# Predicted Label: 7
# Epoch 1/10
# 235/235 [==============================] - 9s 36ms/step - loss: 0.4064 - accuracy: 0.8758 - val_loss: 0.3032 - val_accuracy: 0.9061
# Epoch 2/10
# 235/235 [==============================] - 10s 43ms/step - loss: 0.1592 - accuracy: 0.9505 - val_loss: 0.1510 - val_accuracy: 0.9531
# Epoch 3/10
# 235/235 [==============================] - 16s 69ms/step - loss: 0.1011 - accuracy: 0.9689 - val_loss: 0.1490 - val_accuracy: 0.9488
# Epoch 4/10
# 235/235 [==============================] - 16s 66ms/step - loss: 0.0700 - accuracy: 0.9783 - val_loss: 0.0894 - val_accuracy: 0.9712
# Epoch 5/10
# 235/235 [==============================] - 10s 43ms/step - loss: 0.0514 - accuracy: 0.9842 - val_loss: 0.0929 - val_accuracy: 0.9706
# Epoch 6/10
# 235/235 [==============================] - 9s 40ms/step - loss: 0.0373 - accuracy: 0.9879 - val_loss: 0.0783 - val_accuracy: 0.9738
# Epoch 7/10
# 235/235 [==============================] - 9s 39ms/step - loss: 0.0257 - accuracy: 0.9923 - val_loss: 0.0809 - val_accuracy: 0.9746
# Epoch 8/10
# 235/235 [==============================] - 10s 42ms/step - loss: 0.0192 - accuracy: 0.9941 - val_loss: 0.0606 - val_accuracy: 0.9810
# Epoch 9/10
# 235/235 [==============================] - 10s 42ms/step - loss: 0.0132 - accuracy: 0.9964 - val_loss: 0.0743 - val_accuracy: 0.9779
# Epoch 10/10
# 235/235 [==============================] - 8s 36ms/step - loss: 0.0085 - accuracy: 0.9978 - val_loss: 0.0690 - val_accuracy: 0.9791
# Epoch 1/10
# 235/235 [==============================] - 12s 47ms/step - loss: 1.1803 - accuracy: 0.5924 - val_loss: 0.4344 - val_accuracy: 0.8703
# Epoch 2/10
# 235/235 [==============================] - 11s 47ms/step - loss: 0.3911 - accuracy: 0.8803 - val_loss: 0.3994 - val_accuracy: 0.8786
# Epoch 3/10
# 235/235 [==============================] - 10s 42ms/step - loss: 0.3021 - accuracy: 0.9085 - val_loss: 0.3622 - val_accuracy: 0.8894
# Epoch 4/10
# 235/235 [==============================] - 9s 37ms/step - loss: 0.2498 - accuracy: 0.9244 - val_loss: 0.2309 - val_accuracy: 0.9299
# Epoch 5/10
# 235/235 [==============================] - 11s 45ms/step - loss: 0.2079 - accuracy: 0.9369 - val_loss: 0.2595 - val_accuracy: 0.9161
# Epoch 6/10
# 235/235 [==============================] - 11s 46ms/step - loss: 0.1790 - accuracy: 0.9449 - val_loss: 0.1733 - val_accuracy: 0.9479
# Epoch 7/10
# 235/235 [==============================] - 9s 37ms/step - loss: 0.1554 - accuracy: 0.9530 - val_loss: 0.1536 - val_accuracy: 0.9547
# Epoch 8/10
# 235/235 [==============================] - 10s 44ms/step - loss: 0.1359 - accuracy: 0.9582 - val_loss: 0.1358 - val_accuracy: 0.9582
# Epoch 9/10
# 235/235 [==============================] - 10s 43ms/step - loss: 0.1207 - accuracy: 0.9624 - val_loss: 0.1456 - val_accuracy: 0.9546
# Epoch 10/10
# 235/235 [==============================] - 8s 36ms/step - loss: 0.1081 - accuracy: 0.9667 - val_loss: 0.1624 - val_accuracy: 0.9484
# Epoch 1/10
# 235/235 [==============================] - 8s 33ms/step - loss: 5.0051 - accuracy: 0.8813 - val_loss: 0.7000 - val_accuracy: 0.9314
# Epoch 2/10
# 235/235 [==============================] - 6s 26ms/step - loss: 0.4184 - accuracy: 0.9458 - val_loss: 0.3949 - val_accuracy: 0.9418
# Epoch 3/10
# 235/235 [==============================] - 7s 31ms/step - loss: 0.2375 - accuracy: 0.9592 - val_loss: 0.3703 - val_accuracy: 0.9380
# Epoch 4/10
# 235/235 [==============================] - 6s 26ms/step - loss: 0.1888 - accuracy: 0.9666 - val_loss: 0.3907 - val_accuracy: 0.9475
# Epoch 5/10
# 235/235 [==============================] - 7s 30ms/step - loss: 0.1626 - accuracy: 0.9731 - val_loss: 0.2718 - val_accuracy: 0.9596
# Epoch 6/10
# 235/235 [==============================] - 7s 29ms/step - loss: 0.1451 - accuracy: 0.9763 - val_loss: 0.3089 - val_accuracy: 0.9587
# Epoch 7/10
# 235/235 [==============================] - 7s 29ms/step - loss: 0.1405 - accuracy: 0.9787 - val_loss: 0.3468 - val_accuracy: 0.9627
# Epoch 8/10
# 235/235 [==============================] - 7s 29ms/step - loss: 0.1240 - accuracy: 0.9815 - val_loss: 0.3799 - val_accuracy: 0.9593
# Epoch 9/10
# 235/235 [==============================] - 7s 28ms/step - loss: 0.1223 - accuracy: 0.9833 - val_loss: 0.4395 - val_accuracy: 0.9630
# Epoch 10/10
# 235/235 [==============================] - 7s 31ms/step - loss: 0.1105 - accuracy: 0.9854 - val_loss: 0.3734 - val_accuracy: 0.9684
